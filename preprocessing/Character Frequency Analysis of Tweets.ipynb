# %% [markdown]
# ## Analyzing Characters in Tweets
#
# After finding out that tweets occasionally contain fancy characters such as a downward chart, I started thinking about analyzing the distribution of characters to find out how often such characters can be found in the tweet contents. The data presented here are tweets of selected twitter accounts, namely
# * @business,
# * @BloombergNRG,
# * @ftenergy,
# * @IEA,
# * @LBBW_Research and
# * @FT
# from november 1st through november 14th. Unfortunately, at the time of performing this analysis, no further data is available. However, re-doing the same analysis in a few weeks will increase the credibility of the results.

# %%
import database
from collections import Counter

counter = Counter()
db = database.Database()
with db.get_session() as session:
    tweet_texts = session.query(database.Tweet.text).all()
for text in tweet_texts:
    for char in str(text).lower():
        counter[char] += 1

# %% [markdown]
# Now, let us print out the symbols in reverse order. I would expect the latin alphabet to be most prevalent, common text symbols (such as commas, question marks and so on) to be moderately common and emojis to be even less common. Our goal here is to find out which symbols to look for when working with the text. An initial hypothesis might be that a chart symbol depicting a downward trend is an important indicator of a potentially import economic event.

# %%
for char, count in reversed(counter.most_common()):
    print("Character {} (No. {}) occurred {} time{}.".format(char, ord(char), count, "s" if count > 1 else ""))
# Out:
# Character 🍷 (No. 127863) occurred 1 time.
# Character 🐶 (No. 128054) occurred 1 time.
# Character ñ (No. 241) occurred 1 time.
# Character 방 (No. 48169) occurred 1 time.
# Character 📈 (No. 128200) occurred 1 time.
# Character ç (No. 231) occurred 1 time.
# Character 🎄 (No. 127876) occurred 1 time.
# Character 👍 (No. 128077) occurred 1 time.
# Character » (No. 187) occurred 1 time.
# Character î (No. 238) occurred 1 time.
# Character « (No. 171) occurred 1 time.
# Character 📺 (No. 128250) occurred 1 time.
# Character 🍦 (No. 127846) occurred 1 time.
# Character 📊 (No. 128202) occurred 1 time.
# Character 🏾 (No. 127998) occurred 1 time.
# Character 🙋 (No. 128587) occurred 1 time.
# Character 🐧 (No. 128039) occurred 1 time.
# Character 🐢 (No. 128034) occurred 1 time.
# Character 🐟 (No. 128031) occurred 1 time.
# Character 🦀 (No. 129408) occurred 1 time.
# Character 💧 (No. 128167) occurred 1 time.
# Character á (No. 225) occurred 1 time.
# Character œ (No. 339) occurred 1 time.
# Character ☀ (No. 9728) occurred 1 time.
# Character ⃣ (No. 8419) occurred 1 time.
# Character | (No. 124) occurred 1 time.
# Character è (No. 232) occurred 1 time.
# Character ➡ (No. 10145) occurred 1 time.
# Character ^ (No. 94) occurred 1 time.
# Character ⚠ (No. 9888) occurred 1 time.
# Character 😀 (No. 128512) occurred 1 time.
# Character 🇺 (No. 127482) occurred 1 time.
# Character 🇪 (No. 127466) occurred 1 time.
# Character í (No. 237) occurred 2 times.
# Character 👉 (No. 128073) occurred 2 times.
# Character ` (No. 96) occurred 2 times.
# Character · (No. 183) occurred 2 times.
# Character ] (No. 93) occurred 2 times.
# Character [ (No. 91) occurred 2 times.
# Character 💍 (No. 128141) occurred 3 times.
# Character ⚡ (No. 9889) occurred 3 times.
# Character ó (No. 243) occurred 3 times.
# Character ⏰ (No. 9200) occurred 4 times.
# Character 📅 (No. 128197) occurred 4 times.
# Character 📉 (No. 128201) occurred 5 times.
# Character 🚨 (No. 128680) occurred 5 times.
# Character 🇦 (No. 127462) occurred 5 times.
# Character 🇿 (No. 127487) occurred 5 times.
# Character 🚗 (No. 128663) occurred 5 times.
# Character ️ (No. 65039) occurred 6 times.
# Character € (No. 8364) occurred 9 times.
# Character 👇 (No. 128071) occurred 10 times.
# Character é (No. 233) occurred 14 times.
# Character „ (No. 8222) occurred 16 times.
# Character * (No. 42) occurred 17 times.
# Character – (No. 8211) occurred 23 times.
# Character + (No. 43) occurred 33 times.
# Character £ (No. 163) occurred 35 times.
# Character • (No. 8226) occurred 39 times.
# Character ” (No. 8221) occurred 45 times.
# Character ß (No. 223) occurred 48 times.
# Character “ (No. 8220) occurred 65 times.
# Character — (No. 8212) occurred 147 times.
# Character ! (No. 33) occurred 159 times.
# Character & (No. 38) occurred 166 times.
# Character ; (No. 59) occurred 177 times.
# Character % (No. 37) occurred 190 times.
# Character ‘ (No. 8216) occurred 194 times.
# Character ö (No. 246) occurred 217 times.
# Character $ (No. 36) occurred 237 times.
# Character _ (No. 95) occurred 315 times.
# Character ? (No. 63) occurred 344 times.
# Character … (No. 8230) occurred 392 times.
# Character ä (No. 228) occurred 407 times.
# Character ü (No. 252) occurred 458 times.
# Character \ (No. 92) occurred 872 times.
# Character @ (No. 64) occurred 989 times.
# Character ’ (No. 8217) occurred 1107 times.
# Character 4 (No. 52) occurred 1354 times.
# Character 9 (No. 57) occurred 1365 times.
# Character 3 (No. 51) occurred 1375 times.
# Character 8 (No. 56) occurred 1392 times.
# Character 7 (No. 55) occurred 1477 times.
# Character 6 (No. 54) occurred 1501 times.
# Character 5 (No. 53) occurred 1625 times.
# Character - (No. 45) occurred 1730 times.
# Character 2 (No. 50) occurred 1771 times.
# Character # (No. 35) occurred 1837 times.
# Character " (No. 34) occurred 1947 times.
# Character 1 (No. 49) occurred 2048 times.
# Character 0 (No. 48) occurred 2319 times.
# Character q (No. 113) occurred 2696 times.
# Character j (No. 106) occurred 3436 times.
# Character z (No. 122) occurred 3528 times.
# Character x (No. 120) occurred 3862 times.
# Character v (No. 118) occurred 6562 times.
# Character ) (No. 41) occurred 6771 times.
# Character ( (No. 40) occurred 6774 times.
# Character k (No. 107) occurred 7749 times.
# Character y (No. 121) occurred 7769 times.
# Character , (No. 44) occurred 8560 times.
# Character : (No. 58) occurred 8621 times.
# Character w (No. 119) occurred 9615 times.
# Character . (No. 46) occurred 9643 times.
# Character f (No. 102) occurred 11565 times.
# Character b (No. 98) occurred 11710 times.
# Character g (No. 103) occurred 12598 times.
# Character ' (No. 39) occurred 12912 times.
# Character m (No. 109) occurred 13441 times.
# Character u (No. 117) occurred 15886 times.
# Character d (No. 100) occurred 16616 times.
# Character p (No. 112) occurred 18995 times.
# Character l (No. 108) occurred 20423 times.
# Character / (No. 47) occurred 21599 times.
# Character c (No. 99) occurred 23200 times.
# Character h (No. 104) occurred 23861 times.
# Character r (No. 114) occurred 32573 times.
# Character n (No. 110) occurred 34354 times.
# Character i (No. 105) occurred 34391 times.
# Character a (No. 97) occurred 36436 times.
# Character o (No. 111) occurred 38521 times.
# Character s (No. 115) occurred 40796 times.
# Character e (No. 101) occurred 52099 times.
# Character t (No. 116) occurred 57456 times.
# Character   (No. 32) occurred 81886 times.

# %% [markdown]
# Now, looking at these, we can see that some of these actually carry a meaning. For example, "😱" represents a shocked state and "📈" symbolizes an upwards trend. An easy approach to include such meaning in the tweet text is to replace the visual representation with a textual representation, e.g. to replace "😱" with the word "shocked". I already prepared such a function for this purpose which will come in handy when the data is prepared.
