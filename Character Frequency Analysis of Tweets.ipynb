# %% [markdown]
# ## Analyzing Characters in Tweets
#
# After finding out that tweets occasionally contain fancy characters such as a downward chart, I started thinking about analyzing the distribution of characters to find out how often such characters can be found in the tweet contents. The data presented here are tweets of selected twitter accounts, namely
# * @business,
# * @BloombergNRG,
# * @ftenergy,
# * @IEA,
# * @LBBW_Research and
# * @FT
# from november 1st through november 14th. Unfortunately, at the time of performing this analysis, no further data is available. However, re-doing the same analysis in a few weeks will increase the credibility of the results.

# %%
import database
from collections import Counter

counter = Counter()
db = database.Database()
with db.get_session() as session:
    tweet_texts = session.query(database.Tweet.text).all()
for text in tweet_texts:
    for char in str(text).lower():
        counter[char] += 1

# %% [markdown]
# Now, let us print out the symbols in reverse order. We would expect the latin alphabet to be most prevalent, common text symbols (such as commas, question marks and so on) to be moderately common and emojis to be even less common. Our goal is to find out which symbols to look for when working with the text. An initial hypothesis might be that a chart symbol depicting a downward trend is an important indicator of a potentially import economic event.

# %%
for char, count in reversed(counter.most_common()):
    print("Character {0} occurred {1} time{2}.".format(char, count, "s" if count > 1 else ""))
# Out:
# Character ç occurred 1 time.
# Character 💍 occurred 1 time.
# Character 🎄 occurred 1 time.
# Character » occurred 1 time.
# Character î occurred 1 time.
# Character 🏾 occurred 1 time.
# Character 🙋 occurred 1 time.
# Character 🐧 occurred 1 time.
# Character 🐢 occurred 1 time.
# Character 🐟 occurred 1 time.
# Character 🦀 occurred 1 time.
# Character 节 occurred 1 time.
# Character 棍 occurred 1 time.
# Character 光 occurred 1 time.
# Character 😱 occurred 1 time.
# Character œ occurred 1 time.
# Character ⌛ occurred 1 time.
# Character 🔊 occurred 1 time.
# Character 📨 occurred 1 time.
# Character ﬀ occurred 1 time.
# Character 🇵 occurred 1 time.
# Character 🇯 occurred 1 time.
# Character ≠ occurred 1 time.
# Character ⛽ occurred 1 time.
# Character 🚚 occurred 1 time.
# Character 🛫 occurred 1 time.
# Character 🏥 occurred 1 time.
# Character 📱 occurred 1 time.
# Character 👚 occurred 1 time.
# Character 🎁 occurred 1 time.
# Character 🌱 occurred 1 time.
# Character ½ occurred 1 time.
# Character ♻ occurred 1 time.
# Character 🔌 occurred 1 time.
# Character ⏱ occurred 1 time.
# Character 🇶 occurred 1 time.
# Character ô occurred 1 time.
# Character 🇩 occurred 1 time.
# Character 📍 occurred 1 time.
# Character 📘 occurred 1 time.
# Character ⛵ occurred 1 time.
# Character 🏆 occurred 1 time.
# Character 🙏 occurred 1 time.
# Character 💻 occurred 1 time.
# Character 🚄 occurred 1 time.
# Character à occurred 1 time.
# Character 😀 occurred 1 time.
# Character へ occurred 1 time.
# Character 論 occurred 1 time.
# Character 議 occurred 1 time.
# Character 進 occurred 1 time.
# Character 推 occurred 1 time.
# Character ギ occurred 1 time.
# Character ル occurred 1 time.
# Character ネ occurred 1 time.
# Character エ occurred 1 time.
# Character ン occurred 1 time.
# Character リ occurred 1 time.
# Character ク occurred 1 time.
# Character 会 occurred 1 time.
# Character 事 occurred 1 time.
# Character 理 occurred 1 time.
# Character 僚 occurred 1 time.
# Character 閣 occurred 1 time.
# Character ａ occurred 1 time.
# Character ｅ occurred 1 time.
# Character ｉ occurred 1 time.
# Character ´ occurred 1 time.
# Character ⚽ occurred 2 times.
# Character 🍦 occurred 2 times.
# Character ō occurred 2 times.
# Character è occurred 2 times.
# Character · occurred 2 times.
# Character 💵 occurred 2 times.
# Character 💭 occurred 2 times.
# Character 🇹 occurred 2 times.
# Character 👷 occurred 2 times.
# Character ² occurred 2 times.
# Character → occurred 2 times.
# Character ñ occurred 2 times.
# Character ー occurred 2 times.
# Character 🇻 occurred 3 times.
# Character 🇬 occurred 3 times.
# Character á occurred 3 times.
# Character 🔟 occurred 3 times.
# Character 💡 occurred 3 times.
# Character 🌫 occurred 3 times.
# Character 🇰 occurred 3 times.
# Character 🚰 occurred 3 times.
# Character ø occurred 3 times.
# Character « occurred 3 times.
# Character 📹 occurred 3 times.
# Character 🕑 occurred 4 times.
# Character ‐ occurred 4 times.
# Character ~ occurred 5 times.
# Character ⬇ occurred 5 times.
# Character 🏢 occurred 5 times.
# Character 🇴 occurred 5 times.
# Character 🇽 occurred 5 times.
# Character 🇲 occurred 5 times.
# Character 🇫 occurred 5 times.
# Character | occurred 5 times.
# Character 📅 occurred 6 times.
# Character 🌬 occurred 6 times.
# Character 🌊 occurred 6 times.
# Character 🔋 occurred 6 times.
# Character 📕 occurred 6 times.
# Character ⬆ occurred 6 times.
# Character 📖 occurred 6 times.
# Character 📊 occurred 6 times.
# Character 🇿 occurred 7 times.
# Character ₂ occurred 7 times.
# Character 📉 occurred 8 times.
# Character = occurred 8 times.
# Character 🕜 occurred 9 times.
# Character í occurred 9 times.
# Character 🚨 occurred 10 times.
# Character ° occurred 11 times.
# Character 🇪 occurred 11 times.
# Character 🌍 occurred 12 times.
# Character ] occurred 12 times.
# Character [ occurred 12 times.
# Character „ occurred 12 times.
# Character 🕒 occurred 13 times.
# Character 📺 occurred 14 times.
# Character ☀ occurred 14 times.
# Character ó occurred 14 times.
# Character 🌎 occurred 14 times.
# Character 🇦 occurred 15 times.
# Character 🇧 occurred 16 times.
# Character 🛢 occurred 16 times.
# Character ⏰ occurred 16 times.
# Character 💧 occurred 19 times.
# Character ▶ occurred 20 times.
# Character 🗓 occurred 21 times.
# Character ⚡ occurred 23 times.
# Character ➡ occurred 23 times.
# Character * occurred 24 times.
# Character 📈 occurred 24 times.
# Character 🚗 occurred 26 times.
# Character 🇷 occurred 28 times.
# Character 👍 occurred 28 times.
# Character 🇸 occurred 33 times.
# Character 🇮 occurred 33 times.
# Character 🇺 occurred 33 times.
# Character 🇨 occurred 34 times.
# Character ` occurred 37 times.
# Character € occurred 39 times.
# Character 🎥 occurred 41 times.
# Character é occurred 42 times.
# Character ß occurred 44 times.
# Character 💬 occurred 50 times.
# Character 🇳 occurred 55 times.
# Character £ occurred 71 times.
# Character + occurred 71 times.
# Character ✅ occurred 85 times.
# Character ⃣ occurred 102 times.
# Character 👇 occurred 107 times.
# Character ️ occurred 146 times.
# Character – occurred 159 times.
# Character ” occurred 170 times.
# Character 👉 occurred 176 times.
# Character “ occurred 194 times.
# Character — occurred 199 times.
# Character ö occurred 211 times.
# Character • occurred 231 times.
# Character ! occurred 255 times.
# Character ‘ occurred 369 times.
# Character ä occurred 381 times.
# Character ü occurred 417 times.
# Character _ occurred 616 times.
# Character ? occurred 746 times.
# Character … occurred 986 times.
# Character $ occurred 992 times.
# Character % occurred 1081 times.
# Character & occurred 1423 times.
# Character ; occurred 1455 times.
# Character ’ occurred 2729 times.
# Character 9 occurred 3754 times.
# Character 8 occurred 4066 times.
# Character 4 occurred 4066 times.
# Character - occurred 4252 times.
# Character 6 occurred 4357 times.
# Character 3 occurred 4365 times.
# Character 5 occurred 4683 times.
# Character 7 occurred 4705 times.
# Character \ occurred 4778 times.
# Character " occurred 5139 times.
# Character @ occurred 5674 times.
# Character # occurred 6050 times.
# Character 1 occurred 6811 times.
# Character 2 occurred 7086 times.
# Character q occurred 7628 times.
# Character z occurred 8225 times.
# Character 0 occurred 8339 times.
# Character j occurred 9261 times.
# Character x occurred 10224 times.
# Character ) occurred 16851 times.
# Character ( occurred 16859 times.
# Character k occurred 19473 times.
# Character v occurred 20003 times.
# Character , occurred 22719 times.
# Character : occurred 23854 times.
# Character . occurred 26420 times.
# Character w occurred 26832 times.
# Character y occurred 27144 times.
# Character b occurred 29995 times.
# Character ' occurred 31856 times.
# Character f occurred 32869 times.
# Character g occurred 37897 times.
# Character m occurred 38339 times.
# Character u occurred 42728 times.
# Character d occurred 45532 times.
# Character p occurred 56458 times.
# Character / occurred 60788 times.
# Character l occurred 62750 times.
# Character h occurred 65208 times.
# Character c occurred 70120 times.
# Character r occurred 96623 times.
# Character n occurred 100454 times.
# Character i occurred 102918 times.
# Character a occurred 106769 times.
# Character s occurred 115463 times.
# Character o occurred 120023 times.
# Character e occurred 150736 times.
# Character t occurred 164256 times.
# Character   occurred 247533 times.

# %% [markdown]
# To be continued...
