# %% [markdown]
# ## Analyzing Characters in Tweets
#
# After finding out that tweets occasionally contain fancy characters such as a downward chart, I started thinking about analyzing the distribution of characters to find out how often such characters can be found in the tweet contents. The data presented here are tweets of selected twitter accounts, namely
# * @business,
# * @BloombergNRG,
# * @ftenergy,
# * @IEA,
# * @LBBW_Research and
# * @FT
# from november 1st through november 14th. Unfortunately, at the time of performing this analysis, no further data is available. However, re-doing the same analysis in a few weeks will increase the credibility of the results.

# %%
import database
from collections import Counter

counter = Counter()
db = database.Database()
with db.get_session() as session:
    tweet_texts = session.query(database.Tweet.text).all()
for text in tweet_texts:
    for char in str(text).lower():
        counter[char] += 1

# %% [markdown]
# Now, let us print out the symbols in reverse order. I would expect the latin alphabet to be most prevalent, common text symbols (such as commas, question marks and so on) to be moderately common and emojis to be even less common. Our goal here is to find out which symbols to look for when working with the text. An initial hypothesis might be that a chart symbol depicting a downward trend is an important indicator of a potentially import economic event.

# %%
for char, count in reversed(counter.most_common()):
    print("Character {} (No. {}) occurred {} time{}.".format(char, ord(char), count, "s" if count > 1 else ""))
# Out:
# Character ç (No. 231) occurred 1 time.
# Character 💍 (No. 128141) occurred 1 time.
# Character 🎄 (No. 127876) occurred 1 time.
# Character » (No. 187) occurred 1 time.
# Character î (No. 238) occurred 1 time.
# Character 🏾 (No. 127998) occurred 1 time.
# Character 🙋 (No. 128587) occurred 1 time.
# Character 🐧 (No. 128039) occurred 1 time.
# Character 🐢 (No. 128034) occurred 1 time.
# Character 🐟 (No. 128031) occurred 1 time.
# Character 🦀 (No. 129408) occurred 1 time.
# Character 节 (No. 33410) occurred 1 time.
# Character 棍 (No. 26829) occurred 1 time.
# Character 光 (No. 20809) occurred 1 time.
# Character 😱 (No. 128561) occurred 1 time.
# Character œ (No. 339) occurred 1 time.
# Character ⌛ (No. 8987) occurred 1 time.
# Character 🔊 (No. 128266) occurred 1 time.
# Character 📨 (No. 128232) occurred 1 time.
# Character ﬀ (No. 64256) occurred 1 time.
# Character 🇵 (No. 127477) occurred 1 time.
# Character 🇯 (No. 127471) occurred 1 time.
# Character ≠ (No. 8800) occurred 1 time.
# Character ⛽ (No. 9981) occurred 1 time.
# Character 🚚 (No. 128666) occurred 1 time.
# Character 🛫 (No. 128747) occurred 1 time.
# Character 🏥 (No. 127973) occurred 1 time.
# Character 📱 (No. 128241) occurred 1 time.
# Character 👚 (No. 128090) occurred 1 time.
# Character 🎁 (No. 127873) occurred 1 time.
# Character 🌱 (No. 127793) occurred 1 time.
# Character ½ (No. 189) occurred 1 time.
# Character ♻ (No. 9851) occurred 1 time.
# Character 🔌 (No. 128268) occurred 1 time.
# Character ⏱ (No. 9201) occurred 1 time.
# Character 🇶 (No. 127478) occurred 1 time.
# Character ô (No. 244) occurred 1 time.
# Character 🇩 (No. 127465) occurred 1 time.
# Character 📍 (No. 128205) occurred 1 time.
# Character 📘 (No. 128216) occurred 1 time.
# Character ⛵ (No. 9973) occurred 1 time.
# Character 🏆 (No. 127942) occurred 1 time.
# Character 🙏 (No. 128591) occurred 1 time.
# Character 💻 (No. 128187) occurred 1 time.
# Character 🚄 (No. 128644) occurred 1 time.
# Character à (No. 224) occurred 1 time.
# Character 😀 (No. 128512) occurred 1 time.
# Character へ (No. 12408) occurred 1 time.
# Character 論 (No. 35542) occurred 1 time.
# Character 議 (No. 35696) occurred 1 time.
# Character 進 (No. 36914) occurred 1 time.
# Character 推 (No. 25512) occurred 1 time.
# Character ギ (No. 12462) occurred 1 time.
# Character ル (No. 12523) occurred 1 time.
# Character ネ (No. 12493) occurred 1 time.
# Character エ (No. 12456) occurred 1 time.
# Character ン (No. 12531) occurred 1 time.
# Character リ (No. 12522) occurred 1 time.
# Character ク (No. 12463) occurred 1 time.
# Character 会 (No. 20250) occurred 1 time.
# Character 事 (No. 20107) occurred 1 time.
# Character 理 (No. 29702) occurred 1 time.
# Character 僚 (No. 20698) occurred 1 time.
# Character 閣 (No. 38307) occurred 1 time.
# Character ａ (No. 65345) occurred 1 time.
# Character ｅ (No. 65349) occurred 1 time.
# Character ｉ (No. 65353) occurred 1 time.
# Character ´ (No. 180) occurred 1 time.
# Character ⚽ (No. 9917) occurred 2 times.
# Character 🍦 (No. 127846) occurred 2 times.
# Character ō (No. 333) occurred 2 times.
# Character è (No. 232) occurred 2 times.
# Character · (No. 183) occurred 2 times.
# Character 💵 (No. 128181) occurred 2 times.
# Character 💭 (No. 128173) occurred 2 times.
# Character 🇹 (No. 127481) occurred 2 times.
# Character 👷 (No. 128119) occurred 2 times.
# Character ² (No. 178) occurred 2 times.
# Character → (No. 8594) occurred 2 times.
# Character ñ (No. 241) occurred 2 times.
# Character ー (No. 12540) occurred 2 times.
# Character 🇻 (No. 127483) occurred 3 times.
# Character 🇬 (No. 127468) occurred 3 times.
# Character á (No. 225) occurred 3 times.
# Character 🔟 (No. 128287) occurred 3 times.
# Character 💡 (No. 128161) occurred 3 times.
# Character 🌫 (No. 127787) occurred 3 times.
# Character 🇰 (No. 127472) occurred 3 times.
# Character 🚰 (No. 128688) occurred 3 times.
# Character ø (No. 248) occurred 3 times.
# Character « (No. 171) occurred 3 times.
# Character 📹 (No. 128249) occurred 3 times.
# Character 🕑 (No. 128337) occurred 4 times.
# Character ‐ (No. 8208) occurred 4 times.
# Character ~ (No. 126) occurred 5 times.
# Character ⬇ (No. 11015) occurred 5 times.
# Character 🏢 (No. 127970) occurred 5 times.
# Character 🇴 (No. 127476) occurred 5 times.
# Character 🇽 (No. 127485) occurred 5 times.
# Character 🇲 (No. 127474) occurred 5 times.
# Character 🇫 (No. 127467) occurred 5 times.
# Character • (No. 8226) occurred 231 times.
# Character ! (No. 33) occurred 255 times.
# Character ‘ (No. 8216) occurred 369 times.
# Character ä (No. 228) occurred 381 times.
# Character ü (No. 252) occurred 417 times.
# Character _ (No. 95) occurred 616 times.
# Character ? (No. 63) occurred 746 times.
# Character … (No. 8230) occurred 986 times.
# Character $ (No. 36) occurred 992 times.
# Character % (No. 37) occurred 1081 times.
# Character & (No. 38) occurred 1423 times.
# Character ; (No. 59) occurred 1455 times.
# Character ’ (No. 8217) occurred 2729 times.
# Character 9 (No. 57) occurred 3754 times.
# Character 8 (No. 56) occurred 4066 times.
# Character 4 (No. 52) occurred 4066 times.
# Character - (No. 45) occurred 4252 times.
# Character 6 (No. 54) occurred 4357 times.
# Character 3 (No. 51) occurred 4365 times.
# Character 5 (No. 53) occurred 4683 times.
# Character 7 (No. 55) occurred 4705 times.
# Character \ (No. 92) occurred 4778 times.
# Character " (No. 34) occurred 5139 times.
# Character @ (No. 64) occurred 5674 times.
# Character # (No. 35) occurred 6050 times.
# Character 1 (No. 49) occurred 6811 times.
# Character 2 (No. 50) occurred 7086 times.
# Character q (No. 113) occurred 7628 times.
# Character z (No. 122) occurred 8225 times.
# Character 0 (No. 48) occurred 8339 times.
# Character j (No. 106) occurred 9261 times.
# Character x (No. 120) occurred 10224 times.
# Character ) (No. 41) occurred 16851 times.
# Character ( (No. 40) occurred 16859 times.
# Character k (No. 107) occurred 19473 times.
# Character v (No. 118) occurred 20003 times.
# Character , (No. 44) occurred 22719 times.
# Character : (No. 58) occurred 23854 times.
# Character . (No. 46) occurred 26420 times.
# Character w (No. 119) occurred 26832 times.
# Character y (No. 121) occurred 27144 times.
# Character b (No. 98) occurred 29995 times.
# Character ' (No. 39) occurred 31856 times.
# Character f (No. 102) occurred 32869 times.
# Character g (No. 103) occurred 37897 times.
# Character m (No. 109) occurred 38339 times.
# Character u (No. 117) occurred 42728 times.
# Character d (No. 100) occurred 45532 times.
# Character p (No. 112) occurred 56458 times.
# Character / (No. 47) occurred 60788 times.
# Character l (No. 108) occurred 62750 times.
# Character h (No. 104) occurred 65208 times.
# Character c (No. 99) occurred 70120 times.
# Character r (No. 114) occurred 96623 times.
# Character n (No. 110) occurred 100454 times.
# Character i (No. 105) occurred 102918 times.
# Character a (No. 97) occurred 106769 times.
# Character s (No. 115) occurred 115463 times.
# Character o (No. 111) occurred 120023 times.
# Character e (No. 101) occurred 150736 times.
# Character t (No. 116) occurred 164256 times.
# Character   (No. 32) occurred 247533 times.

# %% [markdown]
# Now, looking at these, we can see that some of these actually carry a meaning. For example, "😱" represents a shocked state and "📈" symbolizes an upwards trend. An easy approach to include such meaning in the tweet text is to replace the visual representation with a textual representation, e.g. to replace "😱" with the word "shocked". I already prepared such a function for this purpose which will come in handy when the data is prepared.
